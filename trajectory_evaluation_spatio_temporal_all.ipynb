# %%
# for reading and validating data
import emeval.input.spec_details as eisd
import emeval.input.phone_view as eipv
import emeval.input.eval_view as eiev

# %%
# Visualization helpers
import emeval.viz.phone_view as ezpv
import emeval.viz.eval_view as ezev
import emeval.viz.geojson as ezgj
import pandas as pd

# %%
# Metrics helpers
import emeval.metrics.dist_calculations as emd
import emeval.metrics.reference_trajectory as emr
# Out:
# /Users/kinjal/miniconda-23.1.0/envs/emissioneval/lib/python3.11/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/kinjal/miniconda-23.1.0/envs/emissioneval/lib/python3.11/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
# For computation
import numpy as np
import math
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
import geopandas as gpd
import shapely as shp
import folium

# %%
DATASTORE_LOC = "bin/data"
AUTHOR_EMAIL = "shankari@eecs.berkeley.edu"
sd_la = eisd.FileSpecDetails(DATASTORE_LOC, AUTHOR_EMAIL, "unimodal_trip_car_bike_mtv_la")
sd_sj = eisd.FileSpecDetails(DATASTORE_LOC, AUTHOR_EMAIL, "car_scooter_brex_san_jose")
sd_ucb = eisd.FileSpecDetails(DATASTORE_LOC, AUTHOR_EMAIL, "train_bus_ebike_mtv_ucb")
# Out:
# After iterating over 1 entries, entry found
# Found spec = Round trip car and bike trip in the South Bay
# Evaluation ran from 2019-07-20T00:00:00-07:00 -> 2020-04-29T17:00:00-07:00
# After iterating over 1 entries, entry found
# Found spec = Multi-modal car scooter BREX trip to San Jose
# Evaluation ran from 2019-07-20T00:00:00-07:00 -> 2020-04-29T17:00:00-07:00
# After iterating over 1 entries, entry found
# Found spec = Multimodal multi-train, multi-bus, ebike trip to UC Berkeley
# Evaluation ran from 2019-07-16T00:00:00-07:00 -> 2020-04-30T00:00:00-07:00

# %%
import importlib
importlib.reload(emr)
# Out:
# <module 'emeval.metrics.reference_trajectory' from '/Users/kinjal/Code/openpath/mobilitynet-analysis-scripts/emeval/metrics/reference_trajectory.py'>

# %%
pv_la = eipv.PhoneView(sd_la)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# Loading transitions for phone ucb-sdb-android-2
# Loading transitions for phone ucb-sdb-android-3
# Loading transitions for phone ucb-sdb-android-4
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# Loading transitions for phone ucb-sdb-ios-2
# Loading transitions for phone ucb-sdb-ios-3
# Loading transitions for phone ucb-sdb-ios-4
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 86 total -> 0 calibration transitions
# ...

# %%
pv_sj = eipv.PhoneView(sd_sj)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# Loading transitions for phone ucb-sdb-android-2
# Loading transitions for phone ucb-sdb-android-3
# Loading transitions for phone ucb-sdb-android-4
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# Loading transitions for phone ucb-sdb-ios-2
# Loading transitions for phone ucb-sdb-ios-3
# Loading transitions for phone ucb-sdb-ios-4
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 86 total -> 0 calibration transitions
# ...

# %%
pv_ucb = eipv.PhoneView(sd_ucb)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# Loading transitions for phone ucb-sdb-android-2
# Loading transitions for phone ucb-sdb-android-3
# Loading transitions for phone ucb-sdb-android-4
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# Loading transitions for phone ucb-sdb-ios-2
# Loading transitions for phone ucb-sdb-ios-3
# Loading transitions for phone ucb-sdb-ios-4
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 102 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 90 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 90 total -> 0 calibration transitions
# ...

# %% [markdown]
# ## Spatial-temporal error calculation

# %%
def get_reference_trajectory_input_tree(pv):
    ref_tree = {}
    
    for phone_os, phone_map in pv.map().items():
        for phone_label, phone_detail_map in phone_map.items():
            for (r_idx, r) in enumerate(phone_detail_map["evaluation_ranges"]):
                if r["eval_role_base"] != "accuracy_control":
                    continue
                for (tr_idx, tr) in enumerate(r["evaluation_trip_ranges"]):
                    for (sr_idx, sr) in enumerate(tr["evaluation_section_ranges"]):
                        # This is a Shapely LineString
                        # print(f"Retrieving ground truth for range {arrow.get(sr['start_ts'])} -> {arrow.get(sr['end_ts'])}")
                        section_gt_leg = pv.spec_details.get_ground_truth_for_leg(tr["trip_id_base"], sr["trip_id_base"], sr["start_ts"], sr["end_ts"])
                        section_gt_shapes = gpd.GeoSeries(eisd.SpecDetails.get_shapes_for_leg(section_gt_leg))
                        if len(section_gt_shapes) == 1:
                            print("No ground truth route for %s %s, must be polygon, skipping..." % (tr["trip_id_base"], sr["trip_id_base"]))
                            assert section_gt_leg["type"] != "TRAVEL", "For %s, %s, %s, %s, %s found type %s" % (phone_os, phone_label, r_idx, tr_idx, sr_idx, section_gt_leg["type"])
                            continue
                        if len(sr['location_df']) == 0:
                            print("No sensed locations found, role = %s skipping..." % (r["eval_role_base"]))
                            # assert r["eval_role_base"] == "power_control", "Found no locations for %s, %s, %s, %s, %s" % (phone_os, phone_label, r_idx, tr_idx, sr_idx)
                            continue
                            
                        print("Processing travel leg %s, %s, %s, %s, %s" %
                              (phone_os, phone_label, r["eval_role_base"], tr["trip_id_base"], sr["trip_id_base"]))
                        # print(f"Ground truth for trip range {arrow.get(tr['start_ts'])} and {arrow.get(tr['end_ts'])} is "
                        #       + f"START: {section_gt_leg['start_loc']['properties']['valid_start_fmt_date']} -> {section_gt_leg['start_loc']['properties']['valid_end_fmt_date']} "
                        #       + f"END:  {section_gt_leg['end_loc']['properties']['valid_start_fmt_date']} -> {section_gt_leg['end_loc']['properties']['valid_end_fmt_date']} ")
                        sec_name = tr["trip_id_base"] + "/" + sr["trip_id_base"] + "_" + str(r_idx)
                        if sec_name not in ref_tree:
                            ref_tree[sec_name] = {
                                "trip_id": tr["trip_id_base"],
                                "section_id": sr["trip_id_base"],
                                "run": r_idx,
                                "ground_truth": {
                                    "leg": section_gt_leg
                                }
                            }
                        
                        assert sec_name in ref_tree
                        e = ref_tree[sec_name]
                        # This is a GeoDataFrame
                        # section_measured_points = get_travel_trajectory(sr['location_df'], polygons)
                        section_measured_points = sr["location_df"]
                        if "temporal_control" not in e:
                            e["temporal_control"] = {}
                            e["start_ts"] = sr["start_ts"]
                            e["end_ts"] = sr["end_ts"]
                        e["temporal_control"][phone_os] = sr
    return ref_tree

def fill_ref_tree_entry(pv, e, function, include_ends=False):
    print("Considering entry %s %s %s and include_ends=%s" % (e["trip_id"], e["section_id"], e["run"], include_ends))
    curr_tz = pv.spec_details.eval_tz
    assert "android" in e["temporal_control"] and "ios" in e["temporal_control"]
    out = emr.ref_and_stats(e, function, 25, tz=curr_tz, include_ends=include_ends)
    if out is not None:
        e["reference_df"], e["reference_stats"] = out

def get_reference_trajectory_tree(pv, ref_tree_root, function, include_ends=False):
    curr_ref_tree = get_reference_trajectory_input_tree(pv)
    ref_tree_root[pv.spec_details.CURR_SPEC_ID] = curr_ref_tree
    [fill_ref_tree_entry(pv, e, function, include_ends) for e in curr_ref_tree.values()]

# %%
import arrow

# %%
# %%capture --no-stdout
# ref_tree_no_ends = {}
# get_reference_trajectory_tree(pv_la, ref_tree_no_ends)
# get_reference_trajectory_tree(pv_sj, ref_tree_no_ends)
# get_reference_trajectory_tree(pv_ucb, ref_tree_no_ends)

# %%
import importlib

# %%
importlib.reload(emr)
# Out:
# <module 'emeval.metrics.reference_trajectory' from '/Users/kinjal/Code/openpath/mobilitynet-analysis-scripts/emeval/metrics/reference_trajectory.py'>

# %%
# breaking_e = ref_tree['train_bus_ebike_mtv_ucb']['mtv_to_berkeley_sf_bart/walk_to_bus_1']

# %%
# %%capture --no-stdout
# ref_trajectory = emr.final_ref_ensemble(breaking_e, 25, tz="America/Los_angeles", include_ends=True)

# %%
# ref_trajectory[1].tail(n=20)

# %%
# curr_map = folium.Map()
# gt_leg_gj = pv_ucb.spec_details.get_geojson_for_leg(breaking_e["ground_truth"]["leg"])
# sensed_section_gj = ezgj.get_geojson_for_loc_df(breaking_e["temporal_control"]["ios"]["location_df"].tail(n=15))
# gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
# sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
# ref_trajectory_gj = ezgj.get_geojson_for_loc_df(ref_trajectory[1], color="blue")
# ref_leg_gj_feature = folium.GeoJson(ref_trajectory_gj, name="reference_values")
# curr_map.add_child(gt_leg_gj_feature)
# curr_map.add_child(sensed_leg_gj_feature)
# curr_map.add_child(ref_leg_gj_feature)
# curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
# folium.LayerControl().add_to(curr_map)
# curr_map

# %%
# map_list = []
# # for i in range(12):
# for i in range(0):
#     breaking_e = ref_tree['train_bus_ebike_mtv_ucb']['mtv_to_berkeley_sf_bart/walk_to_bus_%d' % i]
#     curr_map = folium.Map()
#     gt_leg_gj = pv_ucb.spec_details.get_geojson_for_leg(breaking_e["ground_truth"]["leg"])
#     sensed_section_gj = ezgj.get_geojson_for_loc_df(breaking_e["temporal_control"]["android"]["location_df"])
#     gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
#     sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
#     curr_map.add_child(gt_leg_gj_feature)
#     curr_map.add_child(sensed_leg_gj_feature)
#     curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
#     folium.LayerControl().add_to(curr_map)
#     map_list.append(curr_map)

# %%
# import branca.element as bre
# fig = bre.Figure()
# for i, curr_map in enumerate(map_list):
#     fig.add_subplot(4, 3, i+1).add_child(curr_map)
# fig

# %%
# map_list = []
# # for phone_os in ["android", "ios"]:
# for phone_os in []:
#     breaking_e = ref_tree['train_bus_ebike_mtv_ucb']['mtv_to_berkeley_sf_bart/walk_to_bus_1']
#     curr_map = folium.Map()
#     gt_leg_gj = pv_ucb.spec_details.get_geojson_for_leg(breaking_e["ground_truth"]["leg"])
#     sensed_section_gj = ezgj.get_geojson_for_loc_df(breaking_e["temporal_control"][phone_os]["location_df"])
#     gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
#     sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
#     section_gt_shapes = breaking_e["ground_truth"]["gt_shapes"]
#     filtered_loc = emd.filter_geo_df(breaking_e["temporal_control"][phone_os]["location_df"],
#                       section_gt_shapes.filter(["start_loc","end_loc"]))
#     filtered_section_gj = ezgj.get_geojson_for_loc_df(filtered_loc)
#     filtered_section_gj_feature = folium.GeoJson(filtered_section_gj, name="filtered_values")
#     curr_map.add_child(gt_leg_gj_feature)
#     curr_map.add_child(sensed_leg_gj_feature)
#     curr_map.add_child(filtered_section_gj_feature)
#     curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
#     folium.LayerControl().add_to(curr_map)
#     map_list.append(curr_map)

# %%
# import branca.element as bre
# fig = bre.Figure()
# for i, curr_map in enumerate(map_list):
#     fig.add_subplot(1, 2, i+1).add_child(curr_map)
# fig

# %%
# map_list = []
# # for phone_os in ["android", "ios"]:
# for phone_os in []:
#     breaking_e = ref_tree['train_bus_ebike_mtv_ucb']['mtv_to_berkeley_sf_bart/walk_to_bus_11']
#     curr_map = folium.Map()
#     gt_leg_gj = pv_ucb.spec_details.get_geojson_for_leg(breaking_e["ground_truth"]["leg"])
#     sensed_section_gj = ezgj.get_geojson_for_loc_df(breaking_e["temporal_control"][phone_os]["location_df"])
#     gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
#     sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
#     section_gt_shapes = breaking_e["ground_truth"]["gt_shapes"]
#     filtered_loc = emd.filter_geo_df(breaking_e["temporal_control"][phone_os]["location_df"],
#                       section_gt_shapes.filter(["start_loc","end_loc"]))
#     filtered_section_gj = ezgj.get_geojson_for_loc_df(filtered_loc)
#     filtered_section_gj_feature = folium.GeoJson(filtered_section_gj, name="filtered_values")
#     curr_map.add_child(gt_leg_gj_feature)
#     curr_map.add_child(sensed_leg_gj_feature)
#     curr_map.add_child(filtered_section_gj_feature)
#     curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
#     folium.LayerControl().add_to(curr_map)
#     map_list.append(curr_map)

# %%
# import branca.element as bre
# fig = bre.Figure()
# for i, curr_map in enumerate(map_list):
#     fig.add_subplot(1, 2, i+1).add_child(curr_map)
# fig

# %%
import os
import sys

# %%
def save_ref_tree(ref_tree, function, include_ends=False):
    for timeline in ref_tree.keys():
        print("Working with timeline %s" % timeline)
        tl = ref_tree[timeline]
        prefix = "with_ends" if include_ends else "no_ends"
        for trip_and_leg_and_run in tl.keys():
            curr_run = tl[trip_and_leg_and_run]
            fn = "bin/ref_trees/" + function + "/" + timeline+"/"+prefix+"/"+trip_and_leg_and_run
            save_dir = os.path.dirname(fn)
            os.makedirs(save_dir, exist_ok=True)
            print("Saving data to file %s" % fn)
            if "reference_df" not in curr_run:
                print("Found missing 'reference_df', skipping")
            else:
                curr_run.get('reference_df', pd.DataFrame()).to_csv(fn)

# %%
# save_ref_tree(ref_tree_no_ends, include_ends=False)

# %%
import copy
from concurrent.futures import ThreadPoolExecutor, as_completed

# Each entry is (function, device). device=None means the existing two-stream
# references that merge android + ios. The single-stream and raw references are
# generated per device.
VARIANTS = [
    ("tf", None), ("ct", None), ("dtw", None),
    ("tf_single", "android"), ("tf_single", "ios"),
    ("dtw_single", "android"), ("dtw_single", "ios"),
    ("raw", "android"), ("raw", "ios"),
]

def variant_key(function, device):
    return function if device is None else "%s_%s" % (function, device)

pvs = [pv_la, pv_sj, pv_ucb]

# Build the (device-independent) input trees once per timeline. This is the
# expensive ground-truth/location loading; we do it serially and then fan out
# the per-variant reference construction across the thread pool.
input_trees = {}      # timeline_id -> {sec_name: base_entry}
timeline_tz = {}      # timeline_id -> tz
for pv in pvs:
    input_trees[pv.spec_details.CURR_SPEC_ID] = get_reference_trajectory_input_tree(pv)
    timeline_tz[pv.spec_details.CURR_SPEC_ID] = pv.spec_details.eval_tz

def build_one_reference(function, device, timeline, sec_name, base_entry, tz):
    # Give each (segment, variant) its own entry so threads never mutate shared
    # state. temporal_control (the raw location dataframes) is read-only in the
    # builders, so it can be shared; ground_truth is rebuilt per entry because
    # fill_gt_linestring writes into it.
    e = copy.copy(base_entry)
    e["ground_truth"] = {"leg": base_entry["ground_truth"]["leg"]}
    out = emr.ref_and_stats(e, function, 25, tz=tz, include_ends=True, device=device)
    if out is not None:
        e["reference_df"], e["reference_stats"] = out
    return function, device, timeline, sec_name, e

original_stdout = sys.stdout
sys.stdout = open(os.devnull, 'w')  # Suppress print output from threads

# One task == one reference trajectory (one segment + one variant).
tasks = []
for function, device in VARIANTS:
    for timeline, tree_in in input_trees.items():
        for sec_name, base_entry in tree_in.items():
            tasks.append((function, device, timeline, sec_name, base_entry, timeline_tz[timeline]))

# ref_trees[variant_key][timeline_id][sec_name] = entry (with reference_df / reference_stats)
ref_trees = {variant_key(f, d): {tl: {} for tl in input_trees} for f, d in VARIANTS}


count = 0
total = len(tasks)
with ThreadPoolExecutor(max_workers=5) as executor:
    futures = [executor.submit(build_one_reference, *t) for t in tasks]
    for fut in as_completed(futures):
        function, device, timeline, sec_name, e = fut.result()
        ref_trees[variant_key(function, device)][timeline][sec_name] = e
        count += 1
        print(f"Progress: {count}/{total} ({(count/total)*100:.2f}%)", end="\r", file=original_stdout)

sys.stdout.close()
sys.stdout = original_stdout
print("Built variants: %s" % list(ref_trees.keys()))

# Backward-compatible list for the existing two-stream analysis cells below.
# Order matches the downstream assumption: [0]=tf, [1]=ct, [2]=dtw.
ref_trees_all = [ref_trees["tf"], ref_trees["ct"], ref_trees["dtw"]]

# Backward-compatible aliases used by the downstream visualization cells, which
# expect a {timeline_id: {sec_name: entry}} tree. Use the dtw tree (matches the
# previous behaviour where ref_tree_with_ends ended as the last-built tree).
ref_tree_with_ends = ref_trees["dtw"]
ref_tree = ref_tree_with_ends
# Out:
# No ground truth route for suburb_city_driving_weekend walk_start, must be polygon, skipping...
# Processing travel leg android, ucb-sdb-android-1, accuracy_control, suburb_city_driving_weekend, suburb_city_driving_weekend
# No ground truth route for suburb_city_driving_weekend walk_end, must be polygon, skipping...
# No ground truth route for suburb_bicycling walk_start, must be polygon, skipping...
# Processing travel leg android, ucb-sdb-android-1, accuracy_control, suburb_bicycling, suburb_bicycling
# No ground truth route for suburb_bicycling walk_end, must be polygon, skipping...
# No ground truth route for suburb_city_driving_weekend walk_start, must be polygon, skipping...
# Processing travel leg android, ucb-sdb-android-1, accuracy_control, suburb_city_driving_weekend, suburb_city_driving_weekend
# No ground truth route for suburb_city_driving_weekend walk_end, must be polygon, skipping...
# No ground truth route for suburb_bicycling walk_start, must be polygon, skipping...
# ...

# %%
# Spatial (ground truth) error is now computed inside emr.ref_and_stats and
# stored as reference_stats["gt_error"], so it no longer needs to be injected
# here. To resume from a saved run instead of rebuilding, uncomment the load:
# import pickle
# with open('ref_trees_all.pkl', 'rb') as f:
#     ref_trees_all = pickle.load(f)

# `tree` is used by the aggregation cells below; point it at the dtw tree so we
# iterate over every timeline.
tree = ref_trees_all[2]

with open("segment_stats_all.txt", "w") as f:
    for timeline in tree.keys():
        for segment in tree[timeline].keys():
            segment_stats = {}
            for idx, name in [(0, "tf"), (1, "ct"), (2, "dtw")]:
                entry = ref_trees_all[idx][timeline][segment]
                if "reference_stats" in entry:
                    segment_stats[name] = entry["reference_stats"]
            f.write("timeline: %s\tsegment: %s\t%s\n" % (timeline, segment, segment_stats))
# Out:
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 78 -> 74
# After filtering against polygons 2, 121 -> 104
# After filtering against polygons 2, 121 -> 104
# ...

# %%
# All references (two-stream tf/ct/dtw, single-stream tf/dtw per device, and raw
# per device) are now built in parallel in the thread-pool cell above, so the
# previous serial fill loop is no longer needed. Example access:
e = ref_trees_all[1]["train_bus_ebike_mtv_ucb"]["berkeley_to_mtv_SF_express_bus/commuter_rail_with_tunnels_0"]

# %%
import pickle
with open("ref_trees_all.pkl", 'wb') as f:
    pickle.dump(ref_trees_all, f)
# Save the full variant dict (includes single-stream and raw references) too.
with open("ref_trees.pkl", 'wb') as f:
    pickle.dump(ref_trees, f)

# %%
# Out:
# /Users/kinjal/miniconda-23.1.0/envs/emissioneval/lib/python3.11/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/kinjal/miniconda-23.1.0/envs/emissioneval/lib/python3.11/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# ## Spatio-temporal error of single-stream / raw references vs the two-stream DTW reference
#
# For every segment we treat the two-stream DTW reference as the gold trajectory and
# measure how far each single-stream (TF / DTW per device) and raw-GPS reference is
# from it. For each point in the two-stream DTW reference we find the closest point in
# the candidate trajectory using `sqrt(spatial_dist^2 + (speed_at_point * time_diff)^2)`
# (where `speed_at_point` is the speed of the DTW reference point), and average over all
# reference points.

# %%
# Candidate variants to evaluate against the two-stream DTW reference.
CANDIDATE_VARIANTS = [
    "tf_single_android", "tf_single_ios",
    "dtw_single_android", "dtw_single_ios",
    "raw_android", "raw_ios",
]

st_vs_dtw_rows = []
dtw_tree = ref_trees["dtw"]
for timeline in dtw_tree.keys():
    for segment in dtw_tree[timeline].keys():
        dtw_entry = dtw_tree[timeline][segment]
        if "reference_df" not in dtw_entry:
            continue
        dtw_ref_df = dtw_entry["reference_df"]
        row = {"timeline": timeline, "segment": segment,
               "trajectory_id": segment[:-2]}
        for variant in CANDIDATE_VARIANTS:
            cand_entry = ref_trees[variant].get(timeline, {}).get(segment)
            if cand_entry is None or "reference_df" not in cand_entry:
                row[variant] = np.nan
                continue
            row[variant] = emr.spatio_temporal_error(dtw_ref_df, cand_entry["reference_df"])
        st_vs_dtw_rows.append(row)

st_vs_dtw_df = pd.DataFrame(st_vs_dtw_rows)
print("Computed spatio-temporal error vs two-stream DTW for %d segments" % len(st_vs_dtw_df))
print(st_vs_dtw_df[CANDIDATE_VARIANTS].describe())
st_vs_dtw_df.head()

# %%
# Boxplot of spatio-temporal error per candidate variant (vs two-stream DTW reference)
fig, ax = plt.subplots(figsize=(9, 4))
box_data = [st_vs_dtw_df[v].dropna() for v in CANDIDATE_VARIANTS]
ax.boxplot(box_data, showfliers=False)
ax.set_xticklabels(CANDIDATE_VARIANTS, rotation=30, ha="right")
ax.set_ylabel("Spatio-temporal error vs 2-stream DTW (m)")
ax.set_title("Single-stream / raw reference error vs two-stream DTW reference")
plt.tight_layout()
plt.show()

# Mean error per variant
print(st_vs_dtw_df[CANDIDATE_VARIANTS].mean())

# %%
tf_avg_jerks = []
ct_avg_jerks = []
dtw_avg_jerks = []

tf_coverages = {"coverage_density": [], "coverage_time": [], "coverage_max_gap": [], "gt_error": []}
ct_coverages = {"coverage_density": [], "coverage_time": [], "coverage_max_gap": [], "gt_error": []}
dtw_coverages = {"coverage_density": [], "coverage_time": [], "coverage_max_gap": [], "gt_error": []}

tf_segment_error = {}
ct_segment_error = {}
dtw_segment_error = {}

tf_segment_jerk = {}
ct_segment_jerk = {}
dtw_segment_jerk = {}

for trip in tree.keys():
    # f.write("trip: %s\n" % trip)
    for segment in tree[trip].keys():
        # f.write("\tsegment: %s\n" % segment)
        segment_stats = {}
        if "reference_stats" in ref_trees_all[0][trip][segment] and  "reference_stats" in ref_trees_all[1][trip][segment] and "reference_stats" in ref_trees_all[2][trip][segment]:
            segment_stats["tf"] = ref_trees_all[0][trip][segment]["reference_stats"]
            tf_avg_jerks.append(segment_stats["tf"]["median_jerk"])
            tf_coverages["coverage_density"].append(segment_stats["tf"]["coverage_density"])
            tf_coverages["coverage_time"].append(segment_stats["tf"]["coverage_time"])
            tf_coverages["coverage_max_gap"].append(segment_stats["tf"]["coverage_max_gap"])
            tf_coverages["gt_error"].append(segment_stats["tf"]["gt_error"])
            # f.write("\t\ttf:%s\n" % segment_stats["tf"])

            segment_stats["ct"] = ref_trees_all[1][trip][segment]["reference_stats"]
            ct_avg_jerks.append(segment_stats["ct"]["median_jerk"])
            ct_coverages["coverage_density"].append(segment_stats["ct"]["coverage_density"])
            ct_coverages["coverage_time"].append(segment_stats["ct"]["coverage_time"])
            ct_coverages["coverage_max_gap"].append(segment_stats["ct"]["coverage_max_gap"])
            ct_coverages["gt_error"].append(segment_stats["ct"]["gt_error"])
            # f.write("\t\tct:%s\n" % segment_stats["ct"])

            segment_stats["dtw"] = ref_trees_all[2][trip][segment]["reference_stats"]
            dtw_avg_jerks.append(segment_stats["dtw"]["median_jerk"])
            dtw_coverages["coverage_density"].append(segment_stats["dtw"]["coverage_density"])
            dtw_coverages["coverage_time"].append(segment_stats["dtw"]["coverage_time"])
            dtw_coverages["coverage_max_gap"].append(segment_stats["dtw"]["coverage_max_gap"])
            dtw_coverages["gt_error"].append(segment_stats["dtw"]["gt_error"])

            trajectory_id = segment[:-2] #remove back 2 characters
            if trajectory_id not in tf_segment_error:
                tf_segment_error[trajectory_id] = []
            tf_segment_error[trajectory_id].append(tf_coverages["gt_error"][-1])
            if trajectory_id not in ct_segment_error:
                ct_segment_error[trajectory_id] = []
            ct_segment_error[trajectory_id].append(ct_coverages["gt_error"][-1])
            if trajectory_id not in dtw_segment_error:
                dtw_segment_error[trajectory_id] = []
            dtw_segment_error[trajectory_id].append(dtw_coverages["gt_error"][-1])
            
            if trajectory_id not in tf_segment_jerk:
                tf_segment_jerk[trajectory_id] = []
            tf_segment_jerk[trajectory_id].append(segment_stats["tf"]["median_jerk"])
            if trajectory_id not in ct_segment_jerk:
                ct_segment_jerk[trajectory_id] = []
            ct_segment_jerk[trajectory_id].append(segment_stats["ct"]["median_jerk"])
            if trajectory_id not in dtw_segment_jerk:
                dtw_segment_jerk[trajectory_id] = []
            dtw_segment_jerk[trajectory_id].append(segment_stats["dtw"]["median_jerk"])
            # f.write("\t\tdtw:%s\n" % segment_stats["dtw"])
        
        # f.write("\n")

# %%
#Plot histograms for all the average jerks
#3 subplots
fig, ax = plt.subplots(1, 3, figsize=(18, 3.5), sharex=False, sharey=True)#18,6 for original size
ax[0].hist(tf_avg_jerks, alpha=0.5, bins=10, label='tf', color='b')
ax[1].hist(ct_avg_jerks, alpha=0.5, bins=10, label='ct', color='r')
ax[2].hist(dtw_avg_jerks, alpha=0.5, bins=10, label='dtw', color='g')

ax[0].set_title('Histogram of average jerks')
ax[0].set_xlabel('Jerk value')
ax[0].set_ylabel('Frequency')
ax[0].legend()

ax[1].set_title('Histogram of average jerks')
ax[1].set_xlabel('Jerk value')
ax[1].set_ylabel('Frequency')
ax[1].legend()

ax[2].set_title('Histogram of average jerks')
ax[2].set_xlabel('Jerk value')
ax[2].set_ylabel('Frequency')
ax[2].legend()

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Histogram_avg_jerks_shortened.png', bbox_inches='tight')
plt.show()

# %%
#Histogram of coverage density

fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharex=False, sharey=True)
ax[0].hist(tf_coverages["coverage_density"], alpha=0.5, bins=10, label='tf', color='b')
ax[1].hist(ct_coverages["coverage_density"], alpha=0.5, bins=10, label='ct', color='r')
ax[2].hist(dtw_coverages["coverage_density"], alpha=0.5, bins=10, label='dtw', color='g')

ax[0].set_title('Histogram of coverage density')
ax[0].set_xlabel('Coverage density')
ax[0].set_ylabel('Frequency')
ax[0].legend()

ax[1].set_title('Histogram of coverage density')
ax[1].set_xlabel('Coverage density')
ax[1].set_ylabel('Frequency')
ax[1].legend()

ax[2].set_title('Histogram of coverage density')
ax[2].set_xlabel('Coverage density')
ax[2].set_ylabel('Frequency')
ax[2].legend()

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Histogram_coverage_density.png', bbox_inches='tight')
plt.show()

# %%
#Histogram of coverage time

fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharex=False, sharey=True)
ax[0].hist(tf_coverages["coverage_time"], alpha=0.5, bins=10, label='tf', color='b')
ax[1].hist(ct_coverages["coverage_time"], alpha=0.5, bins=10, label='ct', color='r')
ax[2].hist(dtw_coverages["coverage_time"], alpha=0.5, bins=10, label='dtw', color='g')

ax[0].set_title('Histogram of coverage time')
ax[0].set_xlabel('Coverage time')
ax[0].set_ylabel('Frequency')
ax[0].legend()

ax[1].set_title('Histogram of coverage time')
ax[1].set_xlabel('Coverage time')
ax[1].set_ylabel('Frequency')
ax[1].legend()

ax[2].set_title('Histogram of coverage time')
ax[2].set_xlabel('Coverage time')
ax[2].set_ylabel('Frequency')
ax[2].legend()

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Histogram_coverage_time.png', bbox_inches='tight')
plt.show()

# %%
#Histogram of coverage max gap  

fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharex=False, sharey=True)
ax[0].hist(tf_coverages["coverage_max_gap"], alpha=0.5, bins=10, label='tf', color='b')
ax[1].hist(ct_coverages["coverage_max_gap"], alpha=0.5, bins=10, label='ct', color='r')
ax[2].hist(dtw_coverages["coverage_max_gap"], alpha=0.5, bins=10, label='dtw', color='g')

ax[0].set_title('Histogram of coverage max gap')
ax[0].set_xlabel('Coverage max gap')
ax[0].set_ylabel('Frequency')
ax[0].legend()

ax[1].set_title('Histogram of coverage max gap')
ax[1].set_xlabel('Coverage max gap')
ax[1].set_ylabel('Frequency')
ax[1].legend()

ax[2].set_title('Histogram of coverage max gap')
ax[2].set_xlabel('Coverage max gap')
ax[2].set_ylabel('Frequency')
ax[2].legend()

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Histogram_coverage_max_gap.png', bbox_inches='tight')
plt.show()

# %%
#Histogram of coverage gt error 

fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharex=False, sharey=True)
ax[0].hist(tf_coverages["gt_error"], alpha=0.5, bins=10, label='tf', color='b')
ax[1].hist(ct_coverages["gt_error"], alpha=0.5, bins=10, label='ct', color='r')
ax[2].hist(dtw_coverages["gt_error"], alpha=0.5, bins=10, label='dtw', color='g')

ax[0].set_title('Histogram of coverage gt error')
ax[0].set_xlabel('Coverage gt error')
ax[0].set_ylabel('Frequency')
ax[0].legend()

ax[1].set_title('Histogram of coverage gt error')
ax[1].set_xlabel('Coverage gt error')
ax[1].set_ylabel('Frequency')
ax[1].legend()

ax[2].set_title('Histogram of coverage gt error')
ax[2].set_xlabel('Coverage gt error')
ax[2].set_ylabel('Frequency')
ax[2].legend()

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Histogram_gt_error.png', bbox_inches='tight')
plt.show()

# %%
#2D point graph x-jerk, y-coverage desnity
fig = plt.figure()
ax = fig.add_subplot()

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
iqr_x =np.quantile(dtw_avg_jerks, 0.75) - np.quantile(tf_avg_jerks, 0.25)
max_x = np.quantile(tf_avg_jerks, 0.75) + 1.5 * iqr_x


ax.set_xlim([0, max_x])
ax.set_ylim([0, 1.2])
# ax.set_zlim([0, 20])

ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], marker='o', color='b', label='TF')
ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], marker='^', color='r', label='CT')
ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], marker='s', color='g', label='DTW')

ax.legend()

ax.set_xlabel('Jerk')
ax.set_ylabel('Coverage Density')
# ax.set_zlabel('GT Error')
ax.set_title('Jerk vs Coverage Density')

plt.show()

# %%
#2D point graph x-jerk, y-coverage desnity
fig = plt.figure()
ax = fig.add_subplot()

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
# ax.set_xlim([0, 20])
# ax.set_ylim([0, 20])
# ax.set_zlim([0, 20])

trajectory_ids = list(tf_segment_error.keys())
ax.set_xticks(range(len(trajectory_ids)))

for i in range(len(trajectory_ids)):
    # ax.text(i, tf_coverages["coverage_density"][i], trajectory_ids[i])
    ax.scatter(i, np.mean(tf_segment_error[trajectory_ids[i]]), marker='o', color='b')
    ax.scatter(i, np.mean(ct_segment_error[trajectory_ids[i]]), marker='^', color='r')
    ax.scatter(i, np.mean(dtw_segment_error[trajectory_ids[i]]), marker='s', color='g')   
# ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], marker='o', color='b')
# ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], marker='^', color='r')
# ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], marker='s', color='g')


ax.set_xlabel('Trajectory ID')
ax.set_ylabel('GT Error')
# ax.set_zlabel('GT Error')

plt.show()

# %%
# import re
#2D point graph x-jerk, y-coverage desnity
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
# ax.set_xlim([0, 20])
# ax.set_ylim([0, 20])
# ax.set_zlim([0, 20])
def plot_boxplot(segment_error, ax):
    category_names = ['Fully underground', 'Partially underground', 'Above ground']
    categories_data = {name: [] for name in category_names}
    
    for raw_id, errors in segment_error.items():
        fmt_id = ' '.join(raw_id.split('_')).strip()
        fmt_id_lower = fmt_id.lower()
        if fmt_id_lower == 'mtv to berkeley sf bart/subway underground':
            category = 'Fully underground'
        elif fmt_id_lower in [
            'berkeley to mtv sf express bus/light rail below above ground',
            'berkeley to mtv sf express bus/commuter rail with tunnels'
         ]:
            category = 'Partially underground'
        else:
            category = 'Above ground'
        categories_data[category].extend(errors)
        
    boxes = [categories_data[name] for name in category_names]
    ax.boxplot(boxes, showfliers=False, widths=0.4)
    # Use one word per row inside the x-axis labels to prevent overlapping
    category_labels = [name.replace(' ', '\n') for name in category_names]
    ax.set_xticklabels(category_labels)
    return


def plot_boxplot_jerk(segment_jerk, ax):
    category_names = ['Fully underground', 'Partially underground', 'Above ground']
    categories_data = {name: [] for name in category_names}
    
    for raw_id, jerks in segment_jerk.items():
        fmt_id = ' '.join(raw_id.split('_')).strip()
        fmt_id_lower = fmt_id.lower()
        if fmt_id_lower == 'mtv to berkeley sf bart/subway underground':
            category = 'Fully underground'
        elif fmt_id_lower in [
            'berkeley to mtv sf express bus/light rail below above ground',
            'berkeley to mtv sf express bus/commuter rail with tunnels'
         ]:
            category = 'Partially underground'
        else:
            category = 'Above ground'
        categories_data[category].extend(jerks)
        
    boxes = [categories_data[name] for name in category_names]
    ax.boxplot(boxes, showfliers=False, widths=0.4)
    # Use one word per row inside the x-axis labels to prevent overlapping
    category_labels = [name.replace(' ', '\n') for name in category_names]
    ax.set_xticklabels(category_labels)
    return


# for i in range(len(trajectory_ids)):
#     # ax.text(i, tf_coverages["coverage_density"][i], trajectory_ids[i])
#     ax.scatter(i, np.mean(tf_segment_error[trajectory_ids[i]]), marker='o', color='b')
    
#     ax.scatter(i, np.mean(ct_segment_error[trajectory_ids[i]]), marker='^', color='r')
#     ax.scatter(i, np.mean(dtw_segment_error[trajectory_ids[i]]), marker='s', color='g')   
# ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], marker='o', color='b')
# ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], marker='^', color='r')
# ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], marker='s', color='g')

plot_boxplot(dtw_segment_error, ax)
ax.set_xlabel('Segment Category')
ax.set_ylabel('GT Error')
ax.set_title('DTW GT Error per segment category')
# ax.set_zlabel('GT Error')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/DTW_GT_error_box.png', bbox_inches='tight')
plt.show()

# %%
def print_category_stats(alg_name, segment_error):
    category_names = ['Fully underground', 'Partially underground', 'Above ground']
    categories_data = {name: [] for name in category_names}
    for raw_id, errors in segment_error.items():
        fmt_id = ' '.join(raw_id.split('_')).strip()
        fmt_id_lower = fmt_id.lower()
        if fmt_id_lower == 'mtv to berkeley sf bart/subway underground':
            category = 'Fully underground'
        elif fmt_id_lower in [
            'berkeley to mtv sf express bus/light rail below above ground',
            'berkeley to mtv sf express bus/commuter rail with tunnels'
        ]:
            category = 'Partially underground'
        else:
            category = 'Above ground'
        categories_data[category].extend(errors)
    print(f"=== {alg_name} ===")
    for name in category_names:
        data = categories_data[name]
        mean_val = np.mean(data) if len(data) > 0 else 0
        max_val = np.max(data) if len(data) > 0 else 0
        p75_val = np.percentile(data, 75) if len(data) > 0 else 0
        min_val = np.min(data) if len(data) > 0 else 0
        print(f"Category: {name} (N={len(data)}) -> Range: [{min_val:.5f}, {max_val:.5f}], Mean: {mean_val:.5f}, P75: {p75_val:.5f}")

    all_data = [val for sublist in segment_error.values() for val in sublist]
    print("Total P75 across all categories: %.5f" % np.percentile(all_data, 75))

print_category_stats('DTW', dtw_segment_error)
print_category_stats('TF', tf_segment_error)
print_category_stats('CT', ct_segment_error)

print_category_stats('DTW', dtw_segment_jerk)
print_category_stats('TF', tf_segment_jerk)
print_category_stats('CT', ct_segment_jerk)
# Out:
# === DTW ===
# Category: Fully underground (N=12) -> Range: [0.31722, 4.32035], Mean: 1.71031, P75: 1.86159
# Category: Partially underground (N=24) -> Range: [0.03333, 1.26600], Mean: 0.26251, P75: 0.22749
# Category: Above ground (N=160) -> Range: [0.00000, 3.50098], Mean: 0.06563, P75: 0.05800
# Total P75 across all categories: 0.07233
# === TF ===
# Category: Fully underground (N=12) -> Range: [129.72498, 11549.92685], Mean: 4011.04739, P75: 8286.52453
# Category: Partially underground (N=24) -> Range: [2.60064, 375.59078], Mean: 91.93142, P75: 97.87755
# Category: Above ground (N=160) -> Range: [1.66300, 229.19638], Mean: 11.96309, P75: 10.65369
# Total P75 across all categories: 18.11479
# === CT ===
# Category: Fully underground (N=12) -> Range: [83.85322, 9954.12150], Mean: 1018.63136, P75: 336.53068
# Category: Partially underground (N=24) -> Range: [3.17617, 224.75910], Mean: 58.86602, P75: 72.82018
# ...

# %%
# import re
#2D point graph x-jerk, y-coverage desnity
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
# ax.set_xlim([0, 20])
ax.set_ylim([0, 1800])
# ax.set_zlim([0, 20])

plot_boxplot(tf_segment_error, ax)
# for i in range(len(trajectory_ids)):
#     # ax.text(i, tf_coverages["coverage_density"][i], trajectory_ids[i])
#     ax.scatter(i, np.mean(tf_segment_error[trajectory_ids[i]]), marker='o', color='b')
    
#     ax.scatter(i, np.mean(ct_segment_error[trajectory_ids[i]]), marker='^', color='r')
#     ax.scatter(i, np.mean(dtw_segment_error[trajectory_ids[i]]), marker='s', color='g')   
# ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], marker='o', color='b')
# ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], marker='^', color='r')
# ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], marker='s', color='g')


ax.set_xlabel('Segment Category')
ax.set_ylabel('GT Error')
ax.set_title('TF GT Error per segment category')
# ax.set_zlabel('GT Error')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/TF_GT_error_box.png', bbox_inches='tight')
plt.show()

# %%
# import re
#2D point graph x-jerk, y-coverage desnity
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
# ax.set_xlim([0, 20])
ax.set_ylim([0, 350])
# ax.set_zlim([0, 20])

plot_boxplot(ct_segment_error, ax)

# for i in range(len(trajectory_ids)):
#     # ax.text(i, tf_coverages["coverage_density"][i], trajectory_ids[i])
#     ax.scatter(i, np.mean(tf_segment_error[trajectory_ids[i]]), marker='o', color='b')
    
#     ax.scatter(i, np.mean(ct_segment_error[trajectory_ids[i]]), marker='^', color='r')
#     ax.scatter(i, np.mean(dtw_segment_error[trajectory_ids[i]]), marker='s', color='g')   
# ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], marker='o', color='b')
# ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], marker='^', color='r')
# ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], marker='s', color='g')


ax.set_xlabel('Segment Category')
ax.set_ylabel('GT Error')
ax.set_title('CT GT Error per segment category')
# ax.set_zlabel('GT Error')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/CT_GT_error_box.png', bbox_inches='tight')
plt.show()

# %%
#Box plots of GT error per segment category for each algorithm, all in one figure with 3 subplots
fig, ax = plt.subplots(1, 3, figsize=(15, 5)) #15,5 for original size
#label x and y axis once for the whole figure instead of subplots
plot_boxplot(tf_segment_error, ax[0])
ax[0].set_ylim([0, 1800])
ax[0].set_ylabel('GT Error')
ax[0].set_title('TF GT Error')
plot_boxplot(ct_segment_error, ax[1])
ax[1].set_ylim([0, 350])
ax[1].set_xlabel('Segment Category')
ax[1].set_title('CT GT Error')
plot_boxplot(dtw_segment_error, ax[2])
ax[2].set_title('DTW GT Error')
plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/GT_error_box_all.png', bbox_inches='tight')
plt.show()

# %%
# DTW Jerk boxplot per segment category
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

plot_boxplot_jerk(dtw_segment_jerk, ax)

ax.set_xlabel('Segment Category')
ax.set_ylabel('Median Jerk (m/s^3)')
ax.set_title('DTW Jerk per segment category')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/DTW_jerk_box.png', bbox_inches='tight')
plt.show()

# %%
# TF Jerk boxplot per segment category
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

plot_boxplot_jerk(tf_segment_jerk, ax)

ax.set_xlabel('Segment Category')
ax.set_ylabel('Median Jerk (m/s^3)')
ax.set_title('TF Jerk per segment category')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/TF_jerk_box.png', bbox_inches='tight')
plt.show()

# %%
# CT Jerk boxplot per segment category
fig = plt.figure(figsize=(3.5, 4.5))
ax = fig.add_subplot()

plot_boxplot_jerk(ct_segment_jerk, ax)

ax.set_xlabel('Segment Category')
ax.set_ylabel('Median Jerk (m/s^3)')
ax.set_title('CT Jerk per segment category')

plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/CT_jerk_box.png', bbox_inches='tight')
plt.show()

# %%
#Box plots of Jerk per segment category for each algorithm, all in one figure with 3 subplots
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
plot_boxplot_jerk(tf_segment_jerk, ax[0])
ax[0].set_ylabel('Median Jerk (m/s^3)')
ax[0].set_title('TF Jerk')
plot_boxplot_jerk(ct_segment_jerk, ax[1])
ax[1].set_xlabel('Segment Category')
ax[1].set_title('CT Jerk')
plot_boxplot_jerk(dtw_segment_jerk, ax[2])
ax[2].set_title('DTW Jerk')
plt.tight_layout()
plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Jerk_box_all.png', bbox_inches='tight')
plt.show()

# %%
#Box plots of coverage metrics with each 3 metric having 3 bowplots for ct, tf, and dtw
fig, ax = plt.subplots(1, 3, figsize=(15, 3)) #15,5 for original size

ax[0].set_xticklabels(["CT", "TF", "DTW"])
ax[1].set_xticklabels(["CT", "TF", "DTW"])
ax[2].set_xticklabels(["CT", "TF", "DTW"])

ax[0].boxplot([ct_coverages["coverage_density"], tf_coverages["coverage_density"], dtw_coverages["coverage_density"]], showfliers=False)
ax[0].set_title("Coverage Density")
# ax[0].set_xlabel("CT")
ax[0].set_ylabel("Coverage Density")

ax[1].boxplot([ct_avg_jerks, tf_avg_jerks, dtw_avg_jerks], showfliers=False)

ax[1].set_title("Median Jerk")
# ax[1].set_xlabel("CT")
ax[1].set_ylabel("Median Jerk")

ax[2].boxplot([ct_coverages["gt_error"], tf_coverages["gt_error"], dtw_coverages["gt_error"]], showfliers=False)
ax[2].set_title("GT Error")
# ax[2].set_xlabel("CT")
ax[2].set_ylabel("GT Error")

plt.savefig('../Multi_modal_spatio_temporal_reference_trajectory_creation_and_evaluation/plots/Density_jerk_error_boxes_shortened.png', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/3y/tlc1dl296ssbwyshc10lqf9w0000gp/T/ipykernel_12516/1237380972.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(["CT", "TF", "DTW"])
# /var/folders/3y/tlc1dl296ssbwyshc10lqf9w0000gp/T/ipykernel_12516/1237380972.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(["CT", "TF", "DTW"])
# /var/folders/3y/tlc1dl296ssbwyshc10lqf9w0000gp/T/ipykernel_12516/1237380972.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(["CT", "TF", "DTW"])

# %%
#3D point graph x-jerk, y-coverage desnity, z-coverage gt error
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
ax.set_xlim([0, 20])
ax.set_ylim([0, 1])
ax.set_zlim([0, 20])

ax.scatter(tf_avg_jerks, tf_coverages["coverage_density"], tf_coverages["gt_error"], marker='o', color='b', label='TF')
# ax.scatter(ct_avg_jerks, ct_coverages["coverage_density"], ct_coverages["gt_error"], marker='^', color='r')
ax.scatter(dtw_avg_jerks, dtw_coverages["coverage_density"], dtw_coverages["gt_error"], marker='s', color='g', label='DTW')


ax.set_xlabel('Jerk')
ax.set_ylabel('Coverage Density')
ax.set_zlabel('GT Error')
ax.legend()

plt.show()

# %%
print(list(ref_trees_all[1]["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/city_bus_short_0"]))
# Out:
# ['trip_id', 'section_id', 'run', 'ground_truth', 'temporal_control', 'start_ts', 'end_ts']

# %%
import emeval.metrics.DTW as dtw
df = ref_trees_all[2]["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/city_bus_short_0"]["reference_df"]
dist = []
for idx in range(1, len(df)):
    dist.append(dtw.calDistance(df.iloc[idx].geometry, df.iloc[idx-1].geometry))
print(dist)
# Out:
# [0.0, 2.7645395419781726, 0.8929681991835229, 2.6226021727089717, 2.6226020791530633, 2.622601983118775, 0.9584470784605904, 1.6729140302768006, 2.63640572485166, 2.636405583614094, 2.6364054422396053, 2.636405295814167, 2.6364051570335754, 5.272809883664042, 5.272809312023295, 2.6364044440182743, 4.047902560149947, 3.841092442465789, 5.878121259877621, 2.008079953405459, 5.293709490671433, 10.479353617692066, 5.3001496272644015, 2.6677227776131835, 10.031365492758951, 3.1657028854312794, 2.6318416581195025, 7.8955241978831365, 2.629711755054612, 5.258420385814008, 2.629210013047353, 2.629209892576011, 5.258419423079528, 5.2584189415394675, 2.629209292028919, 2.629209170553742, 2.6292090489634172, 2.62920892972606, 2.629208809484914, 1.8677082598124106, 0.7602193287464636, 2.6247853670536, 2.6247852605584976, 2.624785156637651, 0.21319209053675503, 2.4272343032210832, 5.283617801604126, 2.641808665298953, 2.5216496366041836, 8.27607828277855, 4.158726030371047, 4.158726008950836, 8.3
# ...

# %%
burn, stats = emr.ref_and_stats(ref_trees_all[2]["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/city_bus_short_0"], 'dtw')
print(stats)
# Out:
# After filtering against polygons 2, 83 -> 74
# After filtering against polygons 2, 83 -> 74
# After filtering against polygons 2, 83 -> 74
# After filtering against polygons 2, 83 -> 74
# start a interp
# consec: 0 []
# end a interp
# consec: 0 []
# (array([172,  67,  32,  33,  24,  15,   0,   2,   1,   1]), array([ 0.        ,  2.14505487,  4.29010975,  6.43516462,  8.58021949,
#        10.72527437, 12.87032924, 15.01538411, 17.16043899, 19.30549386,
#        21.45054873]))
# 0
# end a jerk
# (array([162,  41,  18,  25,  20,  27,  15,  16,   7,   3]), array([ 0.        ,  1.23561152,  2.47122304,  3.70683457,  4.94244609,
#         6.17805761,  7.41366913,  8.64928065,  9.88489217, 11.1205037 ,
#        12.35611522]))
# 0
# end i jerk
# Sensor Coneness android: 1.0, ios: 1.0
# GT Coneness android: 2.3550724637681157, ios: 2.3550724637681157
# ...

# %%
ref_tree = ref_tree_with_ends
(len(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/walk_to_bus_11"]['temporal_control']['android']['location_df']), len(ref_tree_with_ends["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/walk_to_bus_11"]['temporal_control']['ios']['location_df']))
# Out:
# (293, 93)

# %%
def get_spatio_temporal_errors(pv):
    spatial_error_df = pd.DataFrame()
    
    for phone_os, phone_map in pv.map().items():
        for phone_label, phone_detail_map in phone_map.items():
            for (r_idx, r) in enumerate(phone_detail_map["evaluation_ranges"]):
                run_errors = []
                for (tr_idx, tr) in enumerate(r["evaluation_trip_ranges"]):
                    trip_errors = []
                    for (sr_idx, sr) in enumerate(tr["evaluation_section_ranges"]):
                        # This is a Shapely LineString
                        section_gt_leg = pv.spec_details.get_ground_truth_for_leg(tr["trip_id_base"], sr["trip_id_base"], sr["start_ts"], sr["end_ts"])
                        section_gt_shapes = gpd.GeoSeries(eisd.SpecDetails.get_shapes_for_leg(section_gt_leg))
                        if len(section_gt_shapes) == 1:
                            print("No ground truth route for %s %s, must be polygon, skipping..." % (tr["trip_id_base"], sr["trip_id_base"]))
                            assert section_gt_leg["type"] != "TRAVEL", "For %s, %s, %s, %s, %s found type %s" % (phone_os, phone_label, r_idx, tr_idx, sr_idx, section_gt_leg["type"])
                            continue
                        if len(sr['location_df']) < 2:
                            print("Too few sensed locations found, role = %s skipping..." % (r["eval_role_base"]))
                            # assert r["eval_role_base"] == "power_control", "Found no locations for %s, %s, %s, %s, %s" % (phone_os, phone_label, r_idx, tr_idx, sr_idx)
                            continue
                            
                        print("Processing travel leg %s, %s, %s, %s, %s" %
                              (phone_os, phone_label, r["eval_role_base"], tr["trip_id_base"], sr["trip_id_base"]))

                        # This is a GeoDataFrame
                        section_geo_df = emd.to_geo_df(sr["location_df"])
                        filtered_section_geo_df = emd.filter_geo_df(section_geo_df, section_gt_shapes)
                        if len(filtered_section_geo_df) < 2:
                            print("Too few filtered locations found, role = %s skipping..." % (r["eval_role_base"]))
                            # assert r["eval_role_base"] == "power_control", "Found no locations for %s, %s, %s, %s, %s" % (phone_os, phone_label, r_idx, tr_idx, sr_idx)
                            continue

                        
                        # This is a GeoDataFrame
                        eval_df = emr.get_int_aligned_trajectory(filtered_section_geo_df, tz=pv.spec_details.eval_tz)
                        sr["resampled_df"] = eval_df
                        spec_name = tr["trip_id_base"]+"/"+sr["trip_id_base"]+"_"+str(r_idx)
                        reference_df = ref_tree[pv.spec_details.CURR_SPEC_ID][spec_name]["reference_df"]

                        # Match these up by timestamp
                        merged_df = pd.merge(eval_df, reference_df, on="ts", how="inner", suffixes=("_e", "_r")).sort_values(by="ts", axis="index")
                        print("len(eval_df) = %d, len(reference_df) = %d len(merged_df) = %d" % (len(eval_df), len(reference_df), len(merged_df)))
                        merged_df["t_distance"] = emd.to_utm_series(gpd.GeoSeries(merged_df.geometry_e)).distance(emd.to_utm_series(gpd.GeoSeries(merged_df.geometry_r)))
                        ne = len(merged_df)
                        curr_spatial_error_df = gpd.GeoDataFrame({"error": merged_df["t_distance"],
                            "ts": merged_df.ts, "geometry": merged_df.geometry_e,
                             "phone_os": np.repeat(phone_os, ne),
                             "phone_label": np.repeat(phone_label, ne),
                             "role": np.repeat(r["eval_role_base"], ne),
                             "timeline": np.repeat(pv.spec_details.CURR_SPEC_ID, ne), 
                              "run": np.repeat(r_idx, ne),
                              "trip_id": np.repeat(tr["trip_id_base"], ne),
                              "section_id": np.repeat(sr["trip_id_base"], ne)
                        })
                        spatial_error_df = pd.concat([spatial_error_df, curr_spatial_error_df], axis="index")
    return spatial_error_df

# %%
st_errors_df = pd.DataFrame()
st_errors_df = pd.concat([st_errors_df, get_spatio_temporal_errors(pv_la)], axis="index")
st_errors_df = pd.concat([st_errors_df, get_spatio_temporal_errors(pv_sj)], axis="index")
st_errors_df = pd.concat([st_errors_df, get_spatio_temporal_errors(pv_ucb)], axis="index")
# Out:
# No ground truth route for suburb_city_driving_weekend walk_start, must be polygon, skipping...
# Processing travel leg android, ucb-sdb-android-1, accuracy_control, suburb_city_driving_weekend, suburb_city_driving_weekend
# After filtering against polygons 3, 259 -> 180
# consec: 0 []
# len(eval_df) = 722, len(reference_df) = 585 len(merged_df) = 0
# No ground truth route for suburb_city_driving_weekend walk_end, must be polygon, skipping...
# No ground truth route for suburb_bicycling walk_start, must be polygon, skipping...
# Processing travel leg android, ucb-sdb-android-1, accuracy_control, suburb_bicycling, suburb_bicycling
# After filtering against polygons 3, 1163 -> 935
# consec: 0 []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 st_errors_df = pd.DataFrame()
# ...

# %%
r2q_map = {"power_control": 0, "HAMFDC": 1, "MAHFDC": 2, "HAHFDC": 3, "MAMFDC": 4, "accuracy_control": 5}
q2r_map = {0: "power", 1: "HAMFDC", 2: "MAHFDC", 3: "HAHFDC", 4: "MAMFDC", 5: "accuracy"}

# %%
st_errors_df["quality"] = st_errors_df.role.apply(lambda r: r2q_map[r])
st_errors_df["label"] = st_errors_df.role.apply(lambda r: r.replace('_control', ''))
timeline_list = ["train_bus_ebike_mtv_ucb", "car_scooter_brex_san_jose", "unimodal_trip_car_bike_mtv_la"]

# %%
st_errors_df.head()
# Out:
#        error            ts                     geometry phone_os  \
# 0  14.766438  1.564274e+09  POINT (-122.08415 37.38964)  android
# 1  18.800178  1.564274e+09  POINT (-122.08415 37.38965)  android
# 2  24.925557  1.564274e+09  POINT (-122.08415 37.38967)  android
# 3  31.961817  1.564274e+09  POINT (-122.08416 37.38969)  android
# 4  39.424228  1.564274e+09  POINT (-122.08416 37.38971)  android
#
#          phone_label              role                       timeline  run  \
# 0  ucb-sdb-android-1  accuracy_control  unimodal_trip_car_bike_mtv_la    0
# 1  ucb-sdb-android-1  accuracy_control  unimodal_trip_car_bike_mtv_la    0
# 2  ucb-sdb-android-1  accuracy_control  unimodal_trip_car_bike_mtv_la    0
# 3  ucb-sdb-android-1  accuracy_control  unimodal_trip_car_bike_mtv_la    0
# 4  ucb-sdb-android-1  accuracy_control  unimodal_trip_car_bike_mtv_la    0
#
#                        trip_id                   section_id  quality     label
# ...

# %%
st_errors_df.query('timeline == "train_bus_ebike_mtv_ucb" & run == 0 & phone_os == "android" & quality == 0').error.head()
# Out:
# Series([], Name: error, dtype: float64)

# %% [markdown]
# ## Reference dataset choice

# %%
def get_spatio_algo(pv):
    spatial_algo_list = []
    
    for phone_os, phone_map in pv.map().items():
        for phone_label, phone_detail_map in phone_map.items():
            for (r_idx, r) in enumerate(phone_detail_map["evaluation_ranges"]):
                run_errors = []
                for (tr_idx, tr) in enumerate(r["evaluation_trip_ranges"]):
                    trip_errors = []
                    for (sr_idx, sr) in enumerate(tr["evaluation_section_ranges"]):
                        spec_name = tr["trip_id_base"]+"/"+sr["trip_id_base"]+"_"+str(r_idx)
                        if spec_name not in ref_tree[pv.spec_details.CURR_SPEC_ID]:
                            print("No reference dataset for %s, skipping" % spec_name)
                            continue
                        e = ref_tree[pv.spec_details.CURR_SPEC_ID][spec_name]
                        curr_ref_algo = {"algo": e["reference_algo"],
                             "phone_os": phone_os,
                             "phone_label": phone_label,
                             "role": r["eval_role_base"],
                             "timeline": pv.spec_details.CURR_SPEC_ID, 
                              "run": r_idx,
                              "trip_id": tr["trip_id_base"],
                              "section_id": sr["trip_id_base"]}
                        spatial_algo_list.append(curr_ref_algo)
    return spatial_algo_list

# %%
spatial_algo_list = []
spatial_algo_list.extend(get_spatio_algo(pv_la))
spatial_algo_list.extend(get_spatio_algo(pv_sj))
spatial_algo_list.extend(get_spatio_algo(pv_ucb))
spatial_algo_df = pd.DataFrame(spatial_algo_list)
# Out:
# No reference dataset for suburb_city_driving_weekend/walk_start_0, skipping
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 spatial_algo_list = []
# ----> 2 spatial_algo_list.extend(get_spatio_algo(pv_la))
#       3 spatial_algo_list.extend(get_spatio_algo(pv_sj))
#       4 spatial_algo_list.extend(get_spatio_algo(pv_ucb))
#
# Cell In[41], line 16, in get_spatio_algo(pv)
#      14                         continue
#      15                     e = ref_tree[pv.spec_details.CURR_SPEC_ID][spec_name]
# ---> 16                     curr_ref_algo = {"algo": e["reference_algo"],
#      17                          "phone_os": phone_os,
#      18                          "phone_label": phone_label,
#      19                          "role": r["eval_role_base"],
#      20                          "timeline": pv.spec_details.CURR_SPEC_ID,
# ...

# %%
ct_set = set(spatial_algo_df[spatial_algo_df.algo == "ct"].section_id.unique())
tf_set = set(spatial_algo_df[spatial_algo_df.algo == "tf"].section_id.unique())
print("CT always = %s,\nTF always = %s,\n BOTH = %s" % (ct_set.difference(tf_set), tf_set.difference(ct_set), tf_set.intersection(ct_set)))

# %% [markdown]
# ## Overall stats

# %%
ifig, ax_array = plt.subplots(nrows=1,ncols=2,figsize=(8,2), sharey=True)

st_errors_df.query("phone_os == 'android' & quality > 0").boxplot(ax = ax_array[0], column=["error"], by=["quality"], showfliers=False)
ax_array[0].set_title('android')
st_errors_df.query("phone_os == 'ios' & quality > 0").boxplot(ax = ax_array[1], column=["error"], by=["quality"], showfliers=False)
ax_array[1].set_title("ios")

for i, ax in enumerate(ax_array):
    # print([t.get_text() for t in ax.get_xticklabels()])
    ax.set_xticklabels([q2r_map[int(t.get_text())] for t in ax.get_xticklabels()])
    ax.set_xlabel("")

ax_array[0].set_ylabel("Spatio-temporal error (meters)")
# ax_array[1][0].set_ylabel("Spatial error (meters)")
ifig.suptitle("Spatio-temporal trajectory error v/s quality (excluding outliers)", y = 1.1)
# ifig.tight_layout()

# %%
ifig, ax_array = plt.subplots(nrows=1,ncols=2,figsize=(8,2), sharey=True)

st_errors_df.query("phone_os == 'android' & quality > 0").boxplot(ax = ax_array[0], column=["error"], by=["quality"])
ax_array[0].set_title('android')
st_errors_df.query("phone_os == 'ios' & quality > 0").boxplot(ax = ax_array[1], column=["error"], by=["quality"])
ax_array[1].set_title("ios")

for i, ax in enumerate(ax_array):
    # print([t.get_text() for t in ax.get_xticklabels()])
    ax.set_xticklabels([q2r_map[int(t.get_text())] for t in ax.get_xticklabels()])
    ax.set_xlabel("")

ax_array[0].set_ylabel("Spatial-temporal error")
# ax_array[1][0].set_ylabel("Spatial error (meters)")
ifig.suptitle("Spatio-temporal trajectory error v/s quality", y = 1.1)
# ifig.tight_layout()

# %% [markdown]
# ### Split out results by timeline

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=3,figsize=(12,6), sharex=False, sharey=False)
timeline_list = ["train_bus_ebike_mtv_ucb", "car_scooter_brex_san_jose", "unimodal_trip_car_bike_mtv_la"]
for i, tl in enumerate(timeline_list):
    st_errors_df.query("timeline == @tl & phone_os == 'android' & quality > 0").boxplot(ax = ax_array[0][i], column=["error"], by=["quality"])
    ax_array[0][i].set_title(tl)
    st_errors_df.query("timeline == @tl & phone_os == 'ios' & quality > 0").boxplot(ax = ax_array[1][i], column=["error"], by=["quality"])
    ax_array[1][i].set_title("")

for i, ax in enumerate(ax_array[0]):
    ax.set_xticklabels([q2r_map[int(t.get_text())] for t in ax.get_xticklabels()])
    ax.set_xlabel("")

for i, ax in enumerate(ax_array[1]):
    ax.set_xticklabels([q2r_map[int(t.get_text())] for t in ax.get_xticklabels()])
    ax.set_xlabel("")

ax_array[0][0].set_ylabel("Spatio-temporal error (android)")
ax_array[1][0].set_ylabel("Spatio-temporal error (ios)")
ifig.suptitle("Spatio-temporal trajectory error v/s quality")
# ifig.tight_layout()

# %% [markdown]
# ### Split out results by section for the most complex timeline (train_bus_ebike_mtv_ucb)

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=4,figsize=(25,10), sharex=True, sharey=True)
timeline_list = ["train_bus_ebike_mtv_ucb"]
for i, tl in enumerate(timeline_list):
    for q in range(1,5):
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'android' & quality == @q")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i][q-1], column=["error"], by=["section_id"])
        ax_array[2*i][q-1].tick_params(axis="x", labelrotation=45)
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'ios' & quality == @q")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i+1][q-1], column=["error"], by=["section_id"])
#        ax_array[i][].set_title("")

def make_acronym(s):
    ssl = s.split("_")
    # print("After splitting %s, we get %s" % (s, ssl))
    if len(ssl) == 0 or len(ssl[0]) == 0:
        return ""
    else:
        return "".join([ss[0] for ss in ssl])

for q in range(1,5):
    ax_array[0][q-1].set_title(q2r_map[q])
    curr_ticks = [t.get_text() for t in ax_array[1][q-1].get_xticklabels()]
    new_ticks = [make_acronym(t) for t in curr_ticks]
    ax_array[1][q-1].set_xticklabels(new_ticks)
    
print(list(zip(curr_ticks, new_ticks)))
# fig.text(0,0,"%s"% list(zip(curr_ticks, new_ticks)))

# %%
timeline_list = ["train_bus_ebike_mtv_ucb"]
for i, tl in enumerate(timeline_list):
    unique_sections = st_errors_df.query("timeline == @tl").section_id.unique()
    ifig, ax_array = plt.subplots(nrows=2,ncols=len(unique_sections),figsize=(40,10), sharex=True, sharey=False)
    for sid, s_name in enumerate(unique_sections):
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'android' & section_id == @s_name & quality > 0")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i][sid], column=["error"], by=["quality"])
        ax_array[2*i][sid].set_title(s_name)
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'ios' & section_id == @s_name & quality > 0")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i+1][sid], column=["error"], by=["quality"])
        ax_array[2*i+1][sid].set_title("")
#        ax_array[i][].set_title("")

# %% [markdown]
# ### Focus only on sections where the max error is > 1000 meters

# %%
timeline_list = ["train_bus_ebike_mtv_ucb"]
for i, tl in enumerate(timeline_list):
    unique_sections = pd.Series(st_errors_df.query("timeline == @tl").section_id.unique())
    sections_with_outliers_mask = unique_sections.apply(lambda s_name: st_errors_df.query("timeline == 'train_bus_ebike_mtv_ucb' & section_id == @s_name").error.max() > 1000)
    sections_with_outliers = unique_sections[sections_with_outliers_mask]   
    ifig, ax_array = plt.subplots(nrows=2,ncols=len(sections_with_outliers),figsize=(17,4), sharex=True, sharey=False)
    for sid, s_name in enumerate(sections_with_outliers):
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'android' & section_id == @s_name & quality > 0")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i][sid], column=["error"], by=["quality"])
        ax_array[2*i][sid].set_title(s_name)
        ax_array[2*i][sid].set_xlabel("")
        sel_df = st_errors_df.query("timeline == @tl & phone_os == 'ios' & section_id == @s_name & quality > 0")
        if len(sel_df) > 0:
            sel_df.boxplot(ax = ax_array[2*i+1][sid], column=["error"], by=["quality"])
        ax_array[2*i+1][sid].set_title("")
        print([t.get_text() for t in ax_array[2*i+1][sid].get_xticklabels()])
        ax_array[2*i+1][sid].set_xticklabels([q2r_map[int(t.get_text())] for t in ax_array[2*i+1][sid].get_xticklabels() if len(t.get_text()) > 0])
        ax_array[2*i+1][sid].set_xlabel("")
    ifig.suptitle("")

# %% [markdown]
# ### Validation of outliers

# %% [markdown]
# #### (express bus iOS, MAHFDC)
#
# ok, so it looks like the error is non-trivial across all runs, but run #1 is the worst and is responsible for the majority of the outliers. And this is borne out by the map, where on run #1, we end up with points in San Leandro!!

# %%
st_errors_df.query("phone_os == 'ios' & quality == 2 & section_id == 'express_bus' & error > 500").run.unique()

# %%
st_errors_df.query("phone_os == 'ios' & quality == 2 & section_id == 'express_bus'").boxplot(column="error", by="run")

# %%
import folium

# %%
importlib.reload(emr)

# %%
gt_leg_gj = ezgj.get_geojson_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["berkeley_to_mtv_SF_express_bus/express_bus_1"]["reference_df"], color="green")
curr_map = ezgj.get_map_for_geojson(gt_leg_gj, name="ground_truth")
ezgj.get_fg_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["berkeley_to_mtv_SF_express_bus/express_bus_1"]["reference_df"], name="gt_points", color="green").add_to(curr_map)

name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))
error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'ios' & quality == 2 & section_id == 'express_bus' & run == 1"))
gt_16k = lambda lr: lr["error"] == error_df.error.max()
folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color="red"), name="sensed_values").add_to(curr_map)
ezgj.get_fg_for_loc_df(error_df, name="sensed_points", color="red", popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)
folium.LayerControl().add_to(curr_map)
curr_map

# %%
gt_section = pv_ucb.map()["ios"]["ucb-sdb-ios-3"]["evaluation_ranges"][1]["evaluation_trip_ranges"][2]["evaluation_section_ranges"][4]
gt_leg = sd_ucb.get_ground_truth_for_leg("berkeley_to_mtv_SF_express_bus", "express_bus", gt_section["start_ts"], gt_section["end_ts"]); print(gt_leg["id"])
curr_map = ezgj.get_map_for_geojson(sd_ucb.get_geojson_for_leg(gt_leg), name="ground_truth")
ezgj.get_fg_for_loc_df(emd.linestring_to_geo_df(eisd.SpecDetails.get_shapes_for_leg(gt_leg)["route"]),
                       name="gt_points", color="green").add_to(curr_map)

name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))

colors = ["red", "yellow", "blue"]
for run in range(3):
    error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'ios' & quality == 2 & section_id == 'express_bus' & run == @run"))
    gt_16k = lambda lr: lr["error"] == error_df.error.max()
    print("max error for run %d is %s" % (run, error_df.error.max()))
    folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color=colors[run]), name="sensed_values").add_to(curr_map)
    ezgj.get_fg_for_loc_df(error_df, name="sensed_points", color=colors[run], popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)

folium.LayerControl().add_to(curr_map)
curr_map

# %% [markdown]
# #### (commuter rail aboveground android, HAMFDC)
#
# Runs along El Camino instead of the Caltrain tracks for a while. Not sure if this is even an outlier.

# %%
st_errors_df.query("phone_os == 'android' & quality == 1 & section_id == 'commuter_rail_aboveground' & error > 500").run.unique()

# %%
ucb_and_back = pv_ucb.map()["android"]["ucb-sdb-android-3"]["evaluation_ranges"][0]; ucb_and_back["trip_id"]
to_trip = ucb_and_back["evaluation_trip_ranges"][0]; print(to_trip["trip_id"])
train_leg = to_trip["evaluation_section_ranges"][2]; print(train_leg["trip_id"])
gt_leg = sd_ucb.get_ground_truth_for_leg(to_trip["trip_id_base"], train_leg["trip_id_base"], train_leg["start_ts"], train_leg["end_ts"]); gt_leg["id"]

# %%
st_errors_df.query("phone_os == 'android' & quality == 1 & section_id == 'commuter_rail_aboveground' & error > 500").boxplot(column="error", by="run")

# %%
gt_leg_gj = ezgj.get_geojson_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/commuter_rail_aboveground_0"]["reference_df"], color="green")
curr_map = ezgj.get_map_for_geojson(gt_leg_gj, name="ground_truth")
ezgj.get_fg_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/commuter_rail_aboveground_0"]["reference_df"], name="gt_points", color="green").add_to(curr_map)

name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))
error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'android' & quality == 1 & section_id == 'commuter_rail_aboveground' & run == 0"))
gt_16k = lambda lr: lr["error"] == error_df.error.max()
folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color="red"), name="sensed_values").add_to(curr_map)
ezgj.get_fg_for_loc_df(error_df, name="sensed_points", color="red", popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)
folium.LayerControl().add_to(curr_map)
curr_map

# %%
unique_sections = pd.Series(st_errors_df.query("timeline == 'train_bus_ebike_mtv_ucb'").section_id.unique())
sections_with_outliers_mask = unique_sections.apply(lambda s_name: st_errors_df.query("timeline == 'train_bus_ebike_mtv_ucb' & section_id == @s_name").error.max() > 100)
unique_sections[sections_with_outliers_mask]

# %% [markdown]
# #### (walk_to_bus android, HAMFDC, HAHFDC)
#
# In the spatial-only accuracy, run 0 was the worst, with a zig-zag out to San Francisco. But the error magnitude was only ~ 3k since it wasn't that far from BART. Now that we account for temporal differences, the error is much larger (9k) but it is only a zig zag out to Ashby. I am guessing that the other error got stripped out because there was no matching timestamp. Not going to worry about that for now...

# %%
st_errors_df.query("phone_os == 'android' & (quality == 1 | quality == 3) & section_id == 'walk_to_bus' & error > 500").run.unique()

# %%
st_errors_df.query("phone_os == 'android' & (quality == 1 | quality == 3) & section_id == 'walk_to_bus' & error > 500")

# %%
st_errors_df.query("phone_os == 'android' & (quality == 1 | quality == 3) & section_id == 'walk_to_bus'").boxplot(column="error", by="run")

# %%
ucb_and_back = pv_ucb.map()["android"]["ucb-sdb-android-2"]["evaluation_ranges"][1]; ucb_and_back["trip_id"]
to_trip = ucb_and_back["evaluation_trip_ranges"][0]; print(to_trip["trip_id"])
wb_leg = to_trip["evaluation_section_ranges"][6]; print(wb_leg["trip_id"])
gt_leg = sd_ucb.get_ground_truth_for_leg(to_trip["trip_id_base"], wb_leg["trip_id_base"], wb_leg["start_ts"], wb_leg["end_ts"]); gt_leg["id"]

# %%
import folium

# %%
gt_leg_gj = ezgj.get_geojson_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/walk_to_bus_0"]["reference_df"], color="green")
curr_map = ezgj.get_map_for_geojson(gt_leg_gj, name="ground_truth")
ezgj.get_fg_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/walk_to_bus_0"]["reference_df"], name="gt_points", color="green").add_to(curr_map)

name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))
error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'android' & quality == 3 & section_id == 'walk_to_bus' & run == 2").sort_index(axis="index"))
gt_16k = lambda lr: lr["error"] == error_df.error.max()
folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color="red"), name="sensed_values").add_to(curr_map)
ezgj.get_fg_for_loc_df(error_df, name="sensed_points", color="red", popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)
folium.LayerControl().add_to(curr_map)
curr_map

# %% [markdown]
# #### (light_rail_below_above_ground, android, accuracy_control)
#
# In this case, the spatial error was bad, but the temporal error is not that terrible, mainly because all the

# %%
st_errors_df.query("phone_os == 'android' & quality == 4 & section_id == 'light_rail_below_above_ground' & error > 100").run.unique()

# %%
st_errors_df.query("phone_os == 'android' & (quality == 4) & section_id == 'light_rail_below_above_ground'").boxplot(column="error", by="run")

# %%
ucb_and_back = pv_ucb.map()["android"]["ucb-sdb-android-2"]["evaluation_ranges"][2]; ucb_and_back["trip_id"]
back_trip = ucb_and_back["evaluation_trip_ranges"][2]; print(back_trip["trip_id"])
lt_leg = back_trip["evaluation_section_ranges"][7]; print(lt_leg["trip_id"])
gt_leg = sd_ucb.get_ground_truth_for_leg(back_trip["trip_id_base"], lt_leg["trip_id_base"], lt_leg["start_ts"], lt_leg["end_ts"]); gt_leg["id"]

# %%
name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))
curr_map = folium.Map()

colors = ["red", "yellow", "blue"]
for run in range(3):
    gt_loc_df = ref_tree["train_bus_ebike_mtv_ucb"]["berkeley_to_mtv_SF_express_bus/light_rail_below_above_ground_%d" % run]["reference_df"]
    gt_leg = ezgj.get_geojson_for_loc_df(gt_loc_df, color=colors[i])
    gt_feature = folium.GeoJson(gt_leg, name="ground_truth_%d" % run).add_to(curr_map)
    ezgj.get_fg_for_loc_df(gt_loc_df,
                       name="gt_points_%d" % run, color="light_%s" % colors[i]).add_to(curr_map)
    error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'android' & quality == 4 & section_id == 'light_rail_below_above_ground' & run == @run"))
    gt_16k = lambda lr: lr["error"] == error_df.error.max()
    print("max error for run %d is %s" % (run, error_df.error.max()))
    folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color=colors[run]), name="sensed_values_%d" % run).add_to(curr_map)
    ezgj.get_fg_for_loc_df(error_df, name="sensed_points_%d" % run, color=colors[run], popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)

curr_map.fit_bounds(gt_feature.get_bounds())
folium.LayerControl().add_to(curr_map)
curr_map

# %% [markdown]
# #### (subway, android, HAMFDC)
#
# This is the poster child for temporal accuracy tracking

# %%
gt_leg_gj = ezgj.get_geojson_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/subway_underground_0"]["reference_df"], color="green")
curr_map = ezgj.get_map_for_geojson(gt_leg_gj, name="ground_truth")
ezgj.get_fg_for_loc_df(ref_tree["train_bus_ebike_mtv_ucb"]["mtv_to_berkeley_sf_bart/subway_underground_0"]["reference_df"], name="gt_points", color="green").add_to(curr_map)

name_err_time = lambda lr: "%d: %d, %s, %s" % (lr["index"], lr["df_idx"], lr["error"], sd_ucb.fmt(lr["ts"], "MM-DD HH:mm:ss"))
error_df = emd.to_loc_df(st_errors_df.query("phone_os == 'android' & quality == 1 & section_id == 'subway_underground' & run == 0").sort_index(axis="index"))
maxes = [error_df.error.max(), error_df[error_df.index > 18].error.max()]
gt_16k = lambda lr: lr["error"] in maxes
folium.GeoJson(ezgj.get_geojson_for_loc_df(error_df, color="red"), name="sensed_values").add_to(curr_map)
ezgj.get_fg_for_loc_df(error_df, name="sensed_points", color="red", popupfn=name_err_time, stickyfn=gt_16k).add_to(curr_map)
folium.LayerControl().add_to(curr_map)
curr_map

# %%
pd.concat([
    error_df.iloc[530:540],
    error_df.iloc[675:685]])

# %%
st_errors_df.query("phone_os == 'android' & (quality == 4) & section_id == 'subway_underground'").boxplot(column="error", by="run")

# %%
import geojson as gj

def display_gt_and_reference(entry, loc_df_label, with_points=False):
    curr_map = folium.Map()
    # print("Using ground truth %s" % entry["ground_truth"]["leg"]["id"])
    gt_leg_gj = ezgj.get_geojson_for_linestring(entry["ground_truth"]["linestring"], color="green")
    gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
    curr_map.add_child(gt_leg_gj_feature)
    if with_points:
        gt_leg_gj_points = ezgj.get_point_markers(gt_leg_gj, name="ground_truth_points", color="green")
        curr_map.add_child(gt_leg_gj_points)
    
    sensed_location_df = entry[loc_df_label]
    # print("Adding section for %s with length %s" % (loc_df_label, len(sensed_location_df)))
    if len(sensed_location_df) > 0:
        sensed_section_gj = gj.Feature(geometry=gj.LineString(coordinates=list(zip(sensed_location_df.longitude, sensed_location_df.latitude))),
                                   properties={"style": {"color": "red"}, "ts": list(sensed_location_df.ts)})
        sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="reference_trajectory")
        print(sensed_leg_gj_feature)
        curr_map.add_child(sensed_leg_gj_feature)
        if with_points:
            sensed_leg_gj_points = ezgj.get_point_markers(sensed_section_gj, name="reference_points", color="red", tz="America/Los_Angeles")
            curr_map.add_child(sensed_leg_gj_points)
    
    curr_map.fit_bounds(gt_leg_gj_feature.get_bounds())
    folium.LayerControl().add_to(curr_map)
    return curr_map

def add_section_and_points(curr_map, eval_section, loc_df_label, layer_name, disp_color, with_points=False):
    sensed_location_df = eval_section[loc_df_label]
    print("Adding section for %s with length %s" % (layer_name, len(sensed_location_df)))
    sensed_section_gj = gj.Feature(geometry=gj.LineString(coordinates=list(zip(sensed_location_df.longitude, sensed_location_df.latitude))),
                                   properties={"style": {"color": disp_color}, "ts": list(sensed_location_df.ts)})
    sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values (%s)" % layer_name)
    curr_map.add_child(sensed_leg_gj_feature)
    if with_points:
        sensed_leg_gj_points = ezgj.get_point_markers(sensed_section_gj, name="sensed_points (%s)" % layer_name,
                                                      color=disp_color, tz="America/Los_Angeles")
        curr_map.add_child(sensed_leg_gj_points)

def display_gt_and_controls(entry, loc_df_label, with_points=False):
    curr_map = folium.Map()
    print("Using ground truth %s" % entry["ground_truth"]["leg"]["id"])
    gt_leg_gj = eisd.SpecDetails.get_geojson_for_leg(entry["ground_truth"]["leg"])
    gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
    curr_map.add_child(gt_leg_gj_feature)
    if with_points:
        gt_leg_gj_points = ezgj.get_point_markers(gt_leg_gj[2], name="ground_truth_points", color="green")
        curr_map.add_child(gt_leg_gj_points)
    
    add_section_and_points(curr_map, entry["temporal_control"]["android"], loc_df_label, "android", "orange", with_points)
    add_section_and_points(curr_map, entry["temporal_control"]["ios"], loc_df_label, "ios", "purple", with_points)
    
    curr_map.fit_bounds(gt_leg_gj_feature.get_bounds())
    folium.LayerControl().add_to(curr_map)
    return curr_map

# %%
##### Considering entry suburb_bicycling suburb_bicycling 0
##### max_gap for tf = 0.03349313290251375 > ct = 0.0008587982795516346 and density 0.7205317565438214 < 0.822728751810466, returning ct len = 958 not tf len = 839

sel_name = "suburb_city_driving_weekend/suburb_city_driving_weekend_3"
e = ref_tree["unimodal_trip_car_bike_mtv_la"][sel_name]
print(e["ground_truth"].keys())
display_gt_and_reference(e, "reference_df", with_points=True)

# %%
ezgj.get_map_for_geojson(eisd.SpecDetails.get_geojson_for_leg(e["ground_truth"]["leg"]))
